# %%
import json

import matplotlib.pyplot as plt

with open('toy_results.txt') as f:
    results = json.load(f)

with open('toy_results_alpha.txt') as f:
    alphas = json.load(f)

with open('toy_results_beta.txt') as f:
    betas = json.load(f)

dims = [2, 5, 10, 20, 50, 100, 150, 200, 300]

# %% [markdown]
# ## Results

# %%
plt.plot(dims,results['F-MCVAE'], label='F-MCVAE')
plt.plot(dims, results['VAE'], label='VAE')
plt.plot(dims, results['IWAE'], label='IWAE')
plt.plot(dims, results['A-MCVAE'], label='A-MCVAE')
plt.plot(dims, results['L-MCVAE'], label='L-MCVAE')
plt.plot(dims, results['RealNVP'], label='RealNVP')
# ... plot others ...
plt.xlabel("Latent Dimension")
plt.ylabel("Discrepancy")
plt.legend()
plt.show()

# %% [markdown]
# ## Alphas

# %%
plt.plot(dims,alphas['F-MCVAE'], label='F-MCVAE')
plt.plot(dims, alphas['VAE'], label='VAE')
plt.plot(dims, alphas['IWAE'], label='IWAE')
plt.plot(dims, alphas['A-MCVAE'], label='A-MCVAE')
plt.plot(dims, alphas['L-MCVAE'], label='L-MCVAE')
plt.plot(dims, alphas['RealNVP'], label='RealNVP')
# ... plot others ...
plt.xlabel("Latent Dimension")
plt.ylabel("Discrepancy")
plt.legend()
plt.show()

# %% [markdown]
# ## Betas

# %%
plt.plot(dims,betas['F-MCVAE'], label='F-MCVAE')
plt.plot(dims, betas['VAE'], label='VAE')
plt.plot(dims, betas['IWAE'], label='IWAE')
plt.plot(dims, betas['A-MCVAE'], label='A-MCVAE')
plt.plot(dims, betas['L-MCVAE'], label='L-MCVAE')
plt.plot(dims, betas['RealNVP'], label='RealNVP')
# ... plot others ...
plt.xlabel("Latent Dimension")
plt.ylabel("Discrepancy")
plt.legend()
plt.show()
